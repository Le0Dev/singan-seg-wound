# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 3.4/3.4 MB 7.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.7/14.7 MB 8.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 8.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.4/7.4 MB 8.2 MB/s eta 0:00:00
# ...
#   Using cached scipy-1.9.0-cp39-cp39-win_amd64.whl (38.6 MB)
# ...
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.3.0
#     Uninstalling Pillow-9.3.0:
#       Successfully uninstalled Pillow-9.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.0
# ...

# %% [markdown]
# # Nouvelle section

# %%
# !python main_train.py --input_name fusc_0002.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256
# Out:
# Random Seed:  7264
# X shape= (512, 512, 4)
# x after imread=== (512, 512, 4)
# X shape= (512, 512, 4)
# x after imread=== (512, 512, 4)
# real_ ==== torch.Size([1, 4, 512, 512])
# real 1 === torch.Size([1, 4, 256, 256])
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(4, 32, kernel_size=(3, 3), stride=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (body): Sequential(
#     (block1): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block2): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
# !python main_train.py --input_name fusc_0003.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256

# %%
# !python main_train.py --input_name fusc_0004.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256

# %%
# !python main_train.py --input_name fusc_0005.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256

# %%
# !python main_train.py --input_name fusc_0006.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256

# %%
# !python main_train.py --input_name fusc_0007.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256

# %%
# !python main_train.py --input_name fusc_0008.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256
# Out:
#   File "C:\Users\leoda\AppData\Local\Temp\ipykernel_27248\2572425693.py", line 1
#     import os!python main_train.py --input_name fusc_0008.png  --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256
#              ^
# SyntaxError: invalid syntax

# %%
import os
from tqdm import tqdm
import torch
import gc
torch.cuda.empty_cache()
gc.collect()

names_to_process = os.listdir('./Input/Images/')

for name in tqdm(names_to_process[1:]):
    command = f"python main_train.py --input_name {name} --nc_z 4 --nc_im 4 --gpu_id 0 --max_size 256"
    # !{command}
    torch.cuda.empty_cache()
    gc.collect()
# Out:
#   6%|▌         | 1/18 [1:38:46<27:59:18, 5926.99s/it]
# Random Seed:  7679
# X shape= (512, 512, 4)
# x after imread=== (512, 512, 4)
# X shape= (512, 512, 4)
# x after imread=== (512, 512, 4)
# real_ ==== torch.Size([1, 4, 512, 512])
# real 1 === torch.Size([1, 4, 256, 256])
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(4, 32, kernel_size=(3, 3), stride=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (body): Sequential(
#     (block1): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block2): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
# ...
